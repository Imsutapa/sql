# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
con = sqlite3.connect("project_database")

# %%
cor=con.cursor()
cor.execute( '''CREATE TABLE customer (
customer_id varchar(10) NOT NULL,
name varchar(100) NOT NULL,
city varchar(65) NOT NULL,
email varchar(45) NOT NULL,
phone_no varchar(15) NOT NULL,
address varchar(100) NOT NULL,
pin_code int NOT NULL,
PRIMARY KEY (customer_id)
) ;''')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20936\3588835500.py in <module>
#       1 cor=con.cursor()
# ----> 2 cor.execute( '''CREATE TABLE customer (
#       3 customer_id varchar(10) NOT NULL,
#       4 name varchar(100) NOT NULL,
#       5 city varchar(65) NOT NULL,
#
# OperationalError: table customer already exists

# %% [markdown]
# # value insert customer table

# %%
cor.execute(''' INSERT INTO `customer` VALUES ('C1001','Steve','Tokyo','steve@gmail.com','4567897652','f.g.road',99),('C1002','john','Sydney','john@gmail.com','9987234567','k.c.road',75001),('C1003','Peter','Kanagawa','peter.parker@mail.com','9969834567','2F Ikenobecho',171),('C1004','Jackson','Tokyo','Jackson@gmail.com','7765834567','24-2, Sendagaya',8429),('C1005','Jack','Lake Buena Vista','Jack@gmail.com','8876345678','1520 E Buena Vista Drive',32830);''')

# %%
cor.execute('''select * from customer;''')
customer_data = pd.DataFrame(cor.fetchall(), columns=[desc[0] for desc in
cor.description])
print(customer_data.head())
# Out:
#   customer_id     name              city                  email    phone_no  \
# 0       C1001    Steve             Tokyo        steve@gmail.com  4567897652
# 1       C1002     john            Sydney         john@gmail.com  9987234567
# 2       C1003    Peter          Kanagawa  peter.parker@mail.com  9969834567
# 3       C1004  Jackson             Tokyo      Jackson@gmail.com  7765834567
# 4       C1005     Jack  Lake Buena Vista         Jack@gmail.com  8876345678
#
#                     address  pin_code
# 0                  f.g.road        99
# 1                  k.c.road     75001
# 2             2F Ikenobecho       171
# 3           24-2, Sendagaya      8429
# 4  1520 E Buena Vista Drive     32830

# %% [markdown]
# #        creat product table

# %%
cor=con.cursor()
cor.execute(''' CREATE TABLE product (
product_id varchar(10) NOT NULL,
product_name varchar(100) NOT NULL,
category varchar(65) NOT NULL,
sub_category varchar(45) NOT NULL,
original_price double NOT NULL,
selling_price double NOT NULL,
stock int NOT NULL,
PRIMARY KEY (product_id)
);''')

# %% [markdown]
# #     creat order details table

# %%
cor=con.cursor()
cor.execute(''' CREATE TABLE order_details(
    order_id INTEGER PRIMARY KEY,
    customer_id TEXT NOT NULL,
    product_id TEXT NOT NULL,
    quantity REAL NOT NULL,
    total_price REAL NOT NULL,
    payment_mode TEXT NOT NULL,
    order_date DATETIME DEFAULT NULL,
    order_status TEXT NOT NULL,
    FOREIGN KEY (customer_id) REFERENCES customer(customer_id),
    FOREIGN KEY (product_id) REFERENCES product(product_id)
);''')

# %% [markdown]
# #            value insert in product table

# %%
cor.execute('''INSERT INTO `product` VALUES('P104','Smartphone','Electronics','phone',45000,40000,20);''')

# %%
cor.execute('''INSERT INTO `product` VALUES ('P102','Chair','furniture','Chairs',20000,15000,10);''')

# %%
cor.execute('''INSERT INTO `product` VALUES ('P110','Table','furniture','Table',5000,10000,5);''')

# %%
cor.execute('''INSERT INTO `product` VALUES ('P112','bed','furniture','bed',10000,15000,12);''')

# %%
cor.execute('''INSERT INTO `product` VALUES ('P114','bed','furniture','bed',2000,1000,6);''')

# %%
cor.execute('''INSERT INTO `product` VALUES ('P115','bed','furniture','bed',4000,5000,10);''')

# %%
cor.execute('''INSERT INTO `product` VALUES ('P101','chair','furniture','phone',450,400,21);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P106','Smartphone','Electronics','phone',4500000,400000,26);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P116','Laptop','Electronics','Laptop',4500,4000,20);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P117','Laptop','Electronics','Laptop',4000,4100,22);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P118','Laptop','Electronics','Laptop',500,520,24);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P119','Laptop','Electronics','Laptop',2000,3000,18);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P120','PC','Electronics','PC',4400,4500,15);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P121','PC','Electronics','PC',5000,6000,19);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P122','PC','Electronics','PC',5200,4500,10);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P123','PC','Electronics','PC',6000,6600,20);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P130','chains','jewellery','chains',150,160,2);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P132','chains','jewellery','chains',50,60,3);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P131','chains','jewellery','chains',100,110,4);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P133','anklets','jewellery','anklets',20,25,5);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P134','anklets','jewellery','anklets',15,20,6);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P135','pendants','jewellery','pendants',30,38,10);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P136','pendants','jewellery','pendants',35,40,7);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P137','hoop','jewellery','hoop',31,38,9);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P138','hoop','jewellery','hoop',49,58,6);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P139','studs','jewellery','studs',21,28,6);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P140','studs','jewellery','studs',15,22,3);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P141','earrings','jewellery','earrings',145,170,1);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P142','earrings','jewellery','earrings',105,120,3);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P143','earrings','jewellery','earrings',100,300,9);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P144','bangles','jewellery','bangles',50,100,15);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P145','bangles','jewellery','bangles',60,110,10);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P146','jhumka','jewellery','jhumka',110,300,14);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P147','jhumka','jewellery','jhumka',200,330,19);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P148','choppers','kitchen utility','choppers',200,400,14);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P149','choppers','kitchen utility','choppers',230,400,12);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P150','dine and serve','kitchen utility','dine and serve',300,500,10);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P151','dine and serve','kitchen utility','dine and serve',390,510,1);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P152','lunch box','kitchen utility','lunch box',300,500,10);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P153','tiffin box','kitchen utility','tiffin box',295,330,17);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P154','pan','kitchen utility','pan',90,168,10);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P155','idli maker','kitchen utility','idli maker',245,100,19);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P156','sunscreen','beauty','sunscreen',100,268,34);''')

# %%
cor.execute('''INSERT INTO `product` VALUES('P157','perfumes','beauty','perfumes',120,268,35);''')

# %%
cor.execute('''INSERT INTO `product` VALUES ('P100','Smartphone','Electronics','chairs',550,500,22);''')

# %%
cor.execute('''INSERT INTO `product` VALUES ('P108','table','furniture','table',4500,4000,24);''')

# %%
cor.execute('''select * from product;''')
product_data = pd.DataFrame(cor.fetchall(), columns=[desc[0] for desc in
cor.description])
print(product_data.head(19))
# Out:
#    product_id product_name     category sub_category  original_price  \
# 0        P104   Smartphone  Electronics        phone         45000.0
# 1        P102        Chair    furniture       Chairs         20000.0
# 2        P110        Table    furniture        Table          5000.0
# 3        P112          bed    furniture          bed         10000.0
# 4        P114          bed    furniture          bed          2000.0
# 5        P115          bed    furniture          bed          4000.0
# 6        P101        chair    furniture        phone           450.0
# 7        P106   Smartphone  Electronics        phone       4500000.0
# 8        P116       Laptop  Electronics       Laptop          4500.0
# 9        P117       Laptop  Electronics       Laptop          4000.0
# 10       P118       Laptop  Electronics       Laptop           500.0
# 11       P119       Laptop  Electronics       Laptop          2000.0
# 12       P120           PC  Electronics           PC          4400.0
# ...

# %%
print(product_data.head(10))
# Out:
#   product_id product_name     category sub_category  original_price  \
# 0       P104   Smartphone  Electronics        phone         45000.0
# 1       P102        Chair    furniture       Chairs         20000.0
# 2       P110        Table    furniture        Table          5000.0
# 3       P112          bed    furniture          bed         10000.0
# 4       P114          bed    furniture          bed          2000.0
# 5       P115          bed    furniture          bed          4000.0
# 6       P101        chair    furniture        phone           450.0
# 7       P106   Smartphone  Electronics        phone       4500000.0
# 8       P116       Laptop  Electronics       Laptop          4500.0
# 9       P117       Laptop  Electronics       Laptop          4000.0
#
#    selling_price  stock
# 0        40000.0     20
# 1        15000.0     10
# 2        10000.0      5
# 3        15000.0     12
# 4         1000.0      6
# 5         5000.0     10
# 6          400.0     21
# ...

# %%
product_data['difference']=product_data['original_price']- product_data['selling_price'] 
plt.plot(product_data['product_name'],product_data['difference'],color='green')

# %% [markdown]
# #               value insert in order details table

# %%
cor.execute('''INSERT INTO `order_details` VALUES(9,'C108','P109',1.0,3000.0,'COD',2022-04-02,'delivery');''')

# %%
cor.execute('''INSERT INTO `order_details` VALUES(26,'C126','P126',1.0,3000.0,'COD',2024-04-02,'delivery');''')

# %%
cor.execute('''INSERT INTO `order_details` VALUES(27,'C127','P127',1.0,5000.0,'COD',2024-08-06,'delivery');''')

# %%
cor.execute('''INSERT INTO `order_details` VALUES(28,'C128','P128',400.0,10000.0,'COD',2023-10-02,'pending');''')

# %%
cor.execute('''INSERT INTO `order_details` VALUES(29,'C129','P129',402.0,5000.0,'COD',2023-11-02,'pending');''')

# %%
cor.execute('''INSERT INTO `order_details` VALUES(30,'C130','P130',401.0,15000.0,'COD',2023-10-09,'pending');''')

# %%
cor.execute('''INSERT INTO `order_details` VALUES(31,'C131','P1',401.0,8000.0,'COD',2024-09-05,'pending');''')

# %%
cor.execute('''INSERT INTO `order_details` VALUES(32,'C132','P132',404.0,9000.0,'COD',2020-10-02,'pending');''')

# %%
cor.execute('''INSERT INTO `order_details` VALUES(33,'C133','P133',405.0,7000.0,'COD',2020-11-01,'pending');''')

# %%
cor.execute('''INSERT INTO `order_details` VALUES(34,'C134','P134',406.0,100.0,'COD',2020-10-02,'pending');''')

# %%
cor.execute('''INSERT INTO `order_details` VALUES(35,'C135','P1',401.0,400.0,'COD',2020-10-05,'pending');''')

# %%
cor.execute('''INSERT INTO `order_details` VALUES(36,'C136','P136',401.0,8000.0,'COD',2021-10-24,'pending');''')

# %%
cor.execute('''INSERT INTO `order_details` VALUES(37,'C137','P137',401.0,14000.0,'COD',2022-10-02,'pending');''')

# %%
cor.execute('''INSERT INTO `order_details` VALUES(38,'C1038','P138',401.0,1200.0,'COD',2022-10-10,'pending');''')

# %%
cor.execute('''INSERT INTO `order_details` VALUES(39,'C139','P139',401.0,1500.0,'COD',2016-10-02,'pending');''')

# %%
cor.execute('''INSERT INTO `order_details` VALUES(40,'C140','P140',401.0,14300.0,'COD',2016-10-10,'pending');''')

# %%
cor.execute('''INSERT INTO `order_details` VALUES(41,'C141','P141',401.0,1600.0,'COD',2015-12-02,'pending');''')

# %%
cor.execute('''INSERT INTO `order_details` VALUES(42,'C142','P142',401.0,18000.0,'COD',2015-10-02,'pending');''')

# %%
cor.execute('''INSERT INTO `order_details` VALUES(43,'C143','P143',401.0,6100.0,'COD',2017-12-02,'pending');''')

# %%
cor.execute('''INSERT INTO `order_details` VALUES(44,'C144','P144',401.0,1900.0,'COD',2018-10-12,'pending');''')

# %%
cor.execute('''INSERT INTO `order_details` VALUES(45,'C1045','P145',401.0,45000.0,'COD',2017-10-02,'pending');''')

# %%
cor.execute('''INSERT INTO `order_details` VALUES(6,'C108','P100',1.0,3000.0,'COD',2023-10-02,'PENDING');''')

# %%
cor.execute('''INSERT INTO `order_details` VALUES(2,'C102','P111',1.0,2000.0,'COD',2023-01-02,'PENDING');''')

# %%
cor.execute('''INSERT INTO `order_details` VALUES(10,'C108','P124',1.0,10000.0,'COD',2022-10-02,'delivery');''')

# %%
cor.execute('''INSERT INTO `order_details` VALUES(12,'C112','P24',1.0,20000.0,'COD',2022-04-04,'delivery');''')

# %%
cor.execute('''INSERT INTO `order_details` VALUES(14,'C110','P024',1.0,90000.0,'COD',2022-08-10,'delivery');''')

# %%
cor.execute('''INSERT INTO `order_details` VALUES(16,'C116','P120',1.0,40000.0,'COD',2022-12-20,'delivery');''')

# %%
cor.execute('''INSERT INTO `order_details` VALUES(25,'C1025','P1',401.0,14000.0,'COD',2023-12-02,'pending');''')

# %%
cor.execute('''select * from order_details;''')
order_details = pd.DataFrame(cor.fetchall(), columns=[desc[0] for desc in
cor.description])
print(order_details.head(40))
# Out:
#     order_id customer_id product_id  quantity  total_price payment_mode  \
# 0          2        C102       P111       1.0       2000.0          COD
# 1          6        C108       P100       1.0       3000.0          COD
# 2          9        C108       P109       1.0       3000.0          COD
# 3         10        C108       P124       1.0      10000.0          COD
# 4         12        C112        P24       1.0      20000.0          COD
# 5         14        C110       P024       1.0      90000.0          COD
# 6         16        C116       P120       1.0      40000.0          COD
# 7         25       C1025         P1     401.0      14000.0          COD
# 8         26        C126       P126       1.0       3000.0          COD
# 9         27        C127       P127       1.0       5000.0          COD
# 10        28        C128       P128     400.0      10000.0          COD
# 11        29        C129       P129     402.0       5000.0          COD
# ...

# %%
sns.catplot(y='total_price',x='order_date',data=order_details.sort_values('total_price',ascending=False),kind='bar',height=6,aspect=3)
plt.show()

# %%
sns.catplot(y='order_date',x='order_status',data=order_details.sort_values('total_price',ascending=False),kind='bar',height=6,aspect=3)
plt.show()

# %%
print(customer_data.nunique())
print(product_data.nunique())
print(order_details.nunique())
# Out:
# customer_id    5
# name           5
# city           4
# email          5
# phone_no       5
# address        5
# pin_code       5
# dtype: int64
# product_id        46
# product_name      24
# category           5
# sub_category      24
# original_price    36
# selling_price     33
# stock             22
# difference        29
# dtype: int64
# order_id        28
# customer_id     26
# product_id      26
# quantity         7
# total_price     22
# payment_mode     1
# order_date      16
# order_status     3
# dtype: int64

# %%
print(customer_data.isnull().sum())
print(product_data.isnull().sum())
print(order_details.isnull().sum())
# Out:
# customer_id    0
# name           0
# city           0
# email          0
# phone_no       0
# address        0
# pin_code       0
# dtype: int64
# product_id        0
# product_name      0
# category          0
# sub_category      0
# original_price    0
# selling_price     0
# stock             0
# difference        0
# dtype: int64
# order_id        0
# customer_id     0
# product_id      0
# quantity        0
# total_price     0
# payment_mode    0
# order_date      0
# order_status    0
# dtype: int64

# %%
# Identify the total number of customers City wise
color = ['darkorange','maroon','green']
customer_data.groupby('city')['customer_id'].count().plot(kind='bar',title='total number of customers City wise',color=color)
# Out:
# <AxesSubplot:title={'center':'total number of customers City wise'}, xlabel='city'>

# %%
#Determine the total number of products available by category
color = ['orange','yellow', 'lightgreen']
product_data.groupby('category')['product_name'].count().plot(kind='bar',title='Types of catagory',color=color)
# Out:
# <AxesSubplot:title={'center':'Types of catagory'}, xlabel='category'>

# %%
#Analyze the distribution of products across sub-categories.
color = ['maroon','yellow', 'green']
product_data.groupby('sub_category')['product_name'].count().plot(kind='bar',title='total number of customers City wise',color=color)
# Out:
# <AxesSubplot:title={'center':'total number of customers City wise'}, xlabel='sub_category'>

# %%
print(product_data.head(10))
# Out:
#   product_id product_name     category sub_category  original_price  \
# 0       P104   Smartphone  Electronics        phone         45000.0
# 1       P102        Chair    furniture       Chairs         20000.0
# 2       P110        Table    furniture        Table          5000.0
# 3       P112          bed    furniture          bed         10000.0
# 4       P114          bed    furniture          bed          2000.0
# 5       P115          bed    furniture          bed          4000.0
# 6       P101        chair    furniture        phone           450.0
# 7       P106   Smartphone  Electronics        phone       4500000.0
# 8       P116       Laptop  Electronics       Laptop          4500.0
# 9       P117       Laptop  Electronics       Laptop          4000.0
#
#    selling_price  stock  difference
# 0        40000.0     20      5000.0
# 1        15000.0     10      5000.0
# 2        10000.0      5     -5000.0
# 3        15000.0     12     -5000.0
# ...

# %%
#Identify products with low stock levels
import matplotlib.pyplot as plt 
low_stock_threshold = 20
# print(product_data['stock'] )
# Filter the DataFrame to identify products with low stock levels
product_data = product_data[product_data['stock'] < low_stock_threshold]

# print("Products with low stock levels:")
# print(product_data)

# Plotting the bar graph
plt.figure(figsize=(5, 6))
c = ['green', 'yellow', 'pink', 'lightblue', 'orange']
plt.bar(product_data['sub_category'], product_data['stock'],color=c)
plt.xlabel('sub_category')
plt.ylabel('Stock Level')
plt.title('Products with Low Stock Levels')
plt.xticks(rotation=40, ha='right',color='maroon')
plt.tight_layout()
plt.show()

# %%
color = ['red','yellow', 'green']
edgecolor = [ 'black','green', 'yellow']

order_details.groupby('order_status')['order_id'].count().plot(kind='bar',title='order status distribution',color=color,
edgecolor=edgecolor,linewidth=3)
# Out:
# <AxesSubplot:title={'center':'order status distribution'}, xlabel='order_status'>

# %%
color = ['red','yellow', 'green']
edgecolor = [ 'black','green', 'yellow']

order_details.groupby('quantity')['total_price'].count().plot(kind='bar',title='total_price vs quantity',color=color,
edgecolor=edgecolor,linewidth=3)
# Out:
# <AxesSubplot:title={'center':'total_price vs quantity'}, xlabel='quantity'>

# %%
order_details.groupby('quantity')['customer_id'].count().plot(title='customer_id vs quantity',kind='pie',startangle = 90)
# Out:
# <AxesSubplot:title={'center':'customer_id vs quantity'}, ylabel='customer_id'>

# %%
order_details.groupby('order_date')['order_status'].count().plot(title='order - date   vs  order - status',kind='pie',startangle = 90)
# Out:
# <AxesSubplot:title={'center':'order - date   vs  order - status'}, ylabel='order_status'>

# %%
order_details.groupby('order_status')['customer_id'].count().plot(title='customer_id vs order status',kind='pie',startangle = 90)
# Out:
# <AxesSubplot:title={'center':'customer_id vs order status'}, ylabel='customer_id'>

# %%
order_details.groupby('customer_id')['order_date'].count().plot(title='customer_id vs order date',kind='pie',startangle = 90)
# Out:
# <AxesSubplot:title={'center':'customer_id vs order date'}, ylabel='order_date'>

# %%
order_details.groupby('total_price')['customer_id'].count().plot(title='customer_id vs total price',kind='bar',color='orange')
# Out:
# <AxesSubplot:title={'center':'customer_id vs total price'}, xlabel='total_price'>

# %%
product_sales = order_details.groupby('quantity')['product_id'].sum().reset_index()

slow_moving_products = product_sales.sort_values(by='quantity').head(10)

print(slow_moving_products)

plt.figure(figsize=(5, 6))
plt.bar(slow_moving_products['product_id'], slow_moving_products['quantity'],color='pink')
plt.xlabel('Product ID')
plt.ylabel('Total Quantity Sold')
plt.title('Top 10 Slow-Moving Products Based on Low Sales')
plt.xticks(rotation=45)
plt.show()
# Out:
#    quantity                                         product_id
# 0       1.0                P111P100P109P124P24P024P120P126P127
# 1     400.0                                               P128
# 2     401.0  P1P130P1P1P136P137P138P139P140P141P142P143P144...
# 3     402.0                                               P129
# 4     404.0                                               P132
# 5     405.0                                               P133
# 6     406.0                                               P134

# %%
product_sale = product_sales.groupby('product_id')['quantity'].sum().reset_index()

best_selling_products = product_sale.sort_values(by='quantity', ascending=False).head(10)
plt.figure(figsize=(5, 6))
plt.bar(best_selling_products['product_id'], best_selling_products['quantity'],color='yellow')
plt.xlabel('Product ID')
plt.ylabel('Total Quantity Sold')
plt.title('Top 10 Best-Selling Products')
plt.xticks(rotation=45)
plt.show()

# %%
customer_data.groupby('pin_code')['name'].count().plot(title='customer name vs pin code',kind='pie')
# Out:
# <AxesSubplot:title={'center':'customer name vs pin code'}, ylabel='name'>

# %%
customer_data.groupby('address')['pin_code'].count().plot(title='customer address  to  pin code',kind='pie')
# Out:
# <AxesSubplot:title={'center':'customer address  to  pin code'}, ylabel='pin_code'>

# %%
customer_data.groupby('phone_no')['address'].count().plot(title='customer phone basis of address',kind='pie')
# Out:
# <AxesSubplot:title={'center':'customer phone basis of address'}, ylabel='address'>

# %%
order_details.groupby('order_date')['total_price'].count().plot(title='year wise total sell',kind='bar',color='green')
# Out:
# <AxesSubplot:title={'center':'year wise total sell'}, xlabel='order_date'>
